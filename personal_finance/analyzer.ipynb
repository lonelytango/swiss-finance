# %%
import source.utilities as util
import source.loader as load
import source.analyzer as analyzer

# %%
analyzer.analyzeChecking(7, 2024)
# Out:
# Total Income: 12330.54
# Income: category
# INCOME    12330.54
# Name: transaction, dtype: float64
# Total Expense: 10775.18
# Expense: category
# CREDIT CARD    -3349.34
# EXPENSE         -408.63
# PROPERTY       -6522.84
# SUBSCRIPTION     -30.67
# UTILITIES       -463.70
# Name: transaction, dtype: float64
# Category: category
# CREDIT CARD     -31.08%
# EXPENSE          -3.79%
# PROPERTY        -60.54%
# SUBSCRIPTION     -0.28%
# UTILITIES         -4.3%
# Name: transaction, dtype: object

# %%
analyzer.analyzeCreditCard(7, 2024)
# Out:
# The file './input/credit/apple/7_2024.csv' does not exist.
# The file './input/credit/td/7_2024.csv' does not exist.
# Total Expense: 4135.39
# Expense: category
# DINING           202.24
# GROCERY           50.16
# HEALTH CARE     1962.20
# OTHER            224.19
# SERVICE            0.03
# SHOPPING        1368.73
# SUBSCRIPTION      36.83
# UTILITIES        291.01
# Name: transaction, dtype: float64
# Category: category
# DINING           4.89%
# GROCERY          1.21%
# HEALTH CARE     47.45%
# OTHER            5.42%
# SERVICE           0.0%
# SHOPPING         33.1%
# SUBSCRIPTION     0.89%
# UTILITIES        7.04%
# Name: transaction, dtype: object

# %%
# Import Wells Fargo
wfDf = load.importWF('./input/credit/wf/7_2024.csv');
df = util.sanitizeDataframe(wfDf);

# making transactions to be positive
# df = filter_df_at_month(df)
util.exportDataframe(df, 'wf')

totalExpense = df.groupby('category')['transaction'].sum()
print(f'Expense: {totalExpense}')

util.plotDataframe(df, '7/2024 WF Credit Card')
# Out:
# Expense: category
# DINING          -202.24
# GROCERY          -50.16
# HEALTH CARE    -1962.20
# OTHER           -222.20
# SHOPPING        -502.59
# SUBSCRIPTION      -2.99
# UTILITIES        -25.00
# Name: transaction, dtype: float64
